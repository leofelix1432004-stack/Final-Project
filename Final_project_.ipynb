# %% [markdown]
# # **Project** **Title**

# %% [markdown]
# **Smart Food Delivery Analytics & Delay Prediction System**

# %% [markdown]
# # **Objective** (**problem** **statment**)

# %% [markdown]
# * Understand how efficiently orders are being delivered.
# * Understand why orders are being cancelled.
# * Determine what factors influence customer ratings.
# * Compare restaurants based on operational performance.
# * Determine whether long delivery times are associated with cancellations.

# %% [markdown]
# Dataset(delivery_data_with_restaurants.csv) Imported from Kaggle.Contains 10000 Row ,12 Colums

# %%
import pandas as pd
from google.colab import files

# Upload CSV
uploaded = files.upload()

# Get filename
file_name = list(uploaded.keys())[0]

# Read CSV
df = pd.read_csv(file_name)

# Show complete data
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

display(df)
# Out:
#      <input type="file" id="files-e2674921-c905-4eb4-b015-19dde562f1fd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e2674921-c905-4eb4-b015-19dde562f1fd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # **Dataset Information**

# %% [markdown]
# This is a simulated dataset containing 10,000 food delivery records generated using Python libraries such as Faker and Pandas. It is designed to reflect realistic food delivery scenarios and can be used for exploratory data analysis (EDA), SQL-based querying, geospatial analysis, and dashboard building with tools like Tableau or Power BI.

# %% [markdown]
# # **Outcome**

# %% [markdown]
# *   Which locations and restaurants have the slowest delivery performance?
# *   What are the major causes of order cancellations, and where do they occur most frequently?
# *  Does faster delivery result in higher customer ratings?
# *  Which restaurants have high order volume but operational problems?
# *  This can reveal whether operational delays are connected with customer cancellations.
